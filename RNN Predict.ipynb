# %%
# !pip install keras-tuner
import os
import pandas as pd
import numpy as np
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from kerastuner.tuners import RandomSearch
import matplotlib.pyplot as plt

# List of Excel files for multiple wells
well_files = ['57.xlsx', '197.xlsx', '218.xlsx', '265.xlsx', '269.xlsx', '341.xlsx']

# Combine data from multiple wells
combined_df = pd.DataFrame()

for file in well_files:
    df = pd.read_excel(file)
    df['VOLUME_DATE'] = pd.to_datetime(df['VOLUME_DATE'])
    df = df.set_index('VOLUME_DATE')

    # Select only the 'ALLOC_OIL_AWO' column
    df = df[['ALLOC_OIL_AWO']]

    # Aggregate data by mean
    aggregated_df = df.resample('D').mean()  # Resample data daily and calculate mean

    # Add a column for well label with "X-" prefix
    well_label = "X-" + file.split('.')[0]  # Add "X-" prefix to well label
    aggregated_df['WELL_LABEL'] = well_label

    # Combine the aggregated data
    combined_df = pd.concat([combined_df, aggregated_df], axis=0)

# Drop NaN values
combined_df = combined_df.dropna()

def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        target = data[i + seq_length]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Initialize lists to hold sequences and targets
X_train_list = []
y_train_list = []
X_test_list = []
y_test_list = []
scalers = {}

# Group by WELL_LABEL and create sequences for each group
sequence_length = 30
for label, group in combined_df.groupby('WELL_LABEL'):
    prod = group['ALLOC_OIL_AWO'].values.reshape(-1, 1)
    dates = group.index[sequence_length:]  # Skip the initial sequence length
    scaler = MinMaxScaler()
    production_data_normalized = scaler.fit_transform(prod)
    X, y = create_sequences(production_data_normalized, sequence_length)

    if len(X) > 0 and len(y) > 0:
        split = int(0.8 * len(X))
        X_train_temp, X_test_temp = X[:split], X[split:]
        y_train_temp, y_test_temp = y[:split], y[split:]
        dates_train, dates_test = dates[:split], dates[split:]

        X_train_list.append(X_train_temp)
        y_train_list.append(y_train_temp)
        X_test_list.append(X_test_temp)
        y_test_list.append(y_test_temp)
        scalers[label] = scaler

# Combine all wells data into single arrays
X_train = np.concatenate(X_train_list, axis=0)
y_train = np.concatenate(y_train_list, axis=0)
X_test = np.concatenate(X_test_list, axis=0)
y_test = np.concatenate(y_test_list, axis=0)

# Display shapes of the final arrays
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")

def build_model(hp):
    model = Sequential()
    model.add(SimpleRNN(units=hp.Int('units', min_value=64, max_value=256, step=32), activation=hp.Choice('activation', values=['relu', 'tanh']), input_shape=(X_train.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])), loss='mse', metrics=['mae'])
    return model

tuner = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=5,
    executions_per_trial=3,
    directory='keras_tuner_logs',
    project_name='oil_production_forecasting'
)

tuner.search(X_train, y_train, epochs=10, validation_data=(X_test, y_test), batch_size=50, verbose=2)

# Get the best hyperparameters
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
best_model = tuner.hypermodel.build(best_hp)

start = time.time()
# Train the best model
best_history = best_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=50, verbose=2)#, callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
end = time.time()
train_dur = end-start
print(f'Total Durasi Training Model: {train_dur} Seconds')

# Retrieve the best hyperparameters
print("Best Hyperparameters:")
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0].values
for key, value in best_hyperparameters.items():
    print(f"{key}: {value}")

# Save the model
model_filename = 'RNN_best.h5'
best_model.save(model_filename)
print(f"Model saved as {model_filename}")

# Plot training history of the best model
plt.figure(figsize=(12, 6))
plt.plot(best_history.history['loss'], label='Training Loss')
plt.plot(best_history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss (Best Model)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Initialize a DataFrame to store evaluation metrics for each well
evaluation_df = pd.DataFrame(columns=['Well', 'Root Mean Squared Error (Training)', 'Mean Absolute Percentage Error (Training)', 'R2 Score (Training)',
                                      'Root Mean Squared Error (WFV_OD)', 'Mean Absolute Percentage Error (WFV_OD)', 'R2 Score (WFV_OD)',
                                      'Root Mean Squared Error (WFV_Op)', 'Mean Absolute Percentage Error (WFV_Op)', 'R2 Score (WFV_Op)'])

# Plot predictions for each well with walk-forward validation and save to a folder
output_folder = "RNN_run"
os.makedirs(output_folder, exist_ok=True)  # Create the output folder if it doesn't exist

for label, group in combined_df.groupby('WELL_LABEL'):
    scaler = scalers[label]

    prod = group['ALLOC_OIL_AWO'].values.reshape(-1, 1)
    dates = group.index[sequence_length:]  # Skip the initial sequence length
    production_data_normalized = scaler.transform(prod)
    X, y = create_sequences(production_data_normalized, sequence_length)

    split = int(0.8 * len(y))
    y_train_actual = scaler.inverse_transform(y[:split].reshape(-1, 1)).flatten()
    y_test_actual = scaler.inverse_transform(y[split:].reshape(-1, 1)).flatten()
    dates_train = dates[:split]
    dates_test = dates[split:]

    # Predict on the training set
    X_train_temp = X_train_list[list(combined_df.groupby('WELL_LABEL').groups.keys()).index(label)]
    y_pred_train_normalized = best_model.predict(X_train_temp)
    y_pred_train_actual = scaler.inverse_transform(y_pred_train_normalized).flatten()

    # Calculate APE for training data
    train_ape = abs((y_train_actual - y_pred_train_actual) / y_train_actual) * 100

    # Predict on the test set
    X_test_temp = X_test_list[list(combined_df.groupby('WELL_LABEL').groups.keys()).index(label)]
    y_pred_normalized = best_model.predict(X_test_temp)
    y_pred_actual = scaler.inverse_transform(y_pred_normalized).flatten()

    # Walk-forward validation for the test set using actual data
    wfv_preds_actual = []
    wfv_ape_actual = []
    walk_forward_dates = dates_test

    # Use only the test data for walk-forward validation
    X_test_for_wfv, y_test_for_wfv = X_test_temp, y[split:]
    for i in range(len(y_test_for_wfv)):
        seq = X_test_for_wfv[i].reshape(1, sequence_length, 1)
        pred = best_model.predict(seq)
        actual_value = scaler.inverse_transform(y_test_for_wfv[i].reshape(1, -1))[0][0]
        predicted_value = scaler.inverse_transform(pred)[0][0]
        wfv_preds_actual.append(predicted_value)
        wfv_ape_actual.append(abs((actual_value - predicted_value) / actual_value) * 100)

    # Walk-forward validation for the test set using predicted data
    wfv_preds_predicted = []
    wfv_ape_predicted = []
    current_sequence_predicted = X_test_temp[0]

    for i in range(len(y_test_actual)):
        seq = current_sequence_predicted.reshape(1, sequence_length, 1)
        pred = best_model.predict(seq)
        predicted_value = scaler.inverse_transform(pred)[0][0]
        wfv_preds_predicted.append(predicted_value)
        wfv_ape_predicted.append(abs((y_test_actual[i] - predicted_value) / y_test_actual[i]) * 100)

        # Update the sequence with the predicted value
        current_sequence_predicted = np.append(current_sequence_predicted[1:], pred)

    # Denormalize the data for plotting
    y_actual = scaler.inverse_transform(y.reshape(-1, 1)).flatten()

    # Plot train, test, and predicted data for each well
    plt.figure(figsize=(18, 7))
    #plt.plot(dates, y_actual, label=f"{label} - Actual", color='blue')
    plt.plot(dates[:split], y_actual[:split], label=f"{label} - Train", color='green')
    plt.plot(dates_test, y_test_actual, label=f"{label} - Test", color='red')
    plt.plot(dates_test, wfv_preds_actual, label=f"{label} - Walk-Forward Predicted (Actual Data)", color='orange', linestyle='dashed')
    plt.plot(dates_test, wfv_preds_predicted, label=f"{label} - Walk-Forward Predicted (Predicted Data)", color='purple', linestyle='dotted')
    plt.title(f'RNN Predictions for {label}')
    plt.xlabel('Date')
    plt.ylabel('Production Volume')
    plt.legend()
    plt.savefig(os.path.join(output_folder, f'{label}_prediction_plot.png'))  # Save the plot as an image
    plt.close()

    # Plot APE for each well
    plt.figure(figsize=(18, 7))
    plt.plot(dates_train, train_ape, label=f"{label} - Training APE", color='blue', linestyle='solid')
    plt.plot(walk_forward_dates, wfv_ape_actual, label=f"{label} - Walk-Forward APE (Actual Data)", color='orange', linestyle='dashed')
    plt.plot(walk_forward_dates, wfv_ape_predicted, label=f"{label} - Walk-Forward APE (Predicted Data)", color='purple', linestyle='dotted')
    plt.axhline(y=10, color='r', linestyle='--', label='10% Error Line')
    plt.title(f'Absolute Percentage Error for {label}')
    plt.xlabel('Date')
    plt.ylabel('APE (%)')
    plt.legend()
    plt.savefig(os.path.join(output_folder, f'{label}_ape_plot.png'))  # Save the APE plot as an image
    plt.close()

    # Calculate evaluation metrics for the well
    rmse = np.sqrt(mean_squared_error(y_train_actual, y_pred_train_actual))
    mape = mean_absolute_percentage_error(y_train_actual, y_pred_train_actual)
    r2 = r2_score(y_train_actual, y_pred_train_actual)

    rmse_wfod = np.sqrt(mean_squared_error(y_test_actual, wfv_preds_actual))
    mape_wfod = mean_absolute_percentage_error(y_test_actual, wfv_preds_actual)
    r2_wfod = r2_score(y_test_actual, wfv_preds_actual)

    rmse_wfp = np.sqrt(mean_squared_error(y_test_actual, wfv_preds_predicted))
    mape_wfp = mean_absolute_percentage_error(y_test_actual, wfv_preds_predicted)
    r2_wfp = r2_score(y_test_actual, wfv_preds_predicted)
    # Append metrics to DataFrame
    evaluation_df = pd.concat([evaluation_df, pd.DataFrame([{
        'Well': label, 'Root Mean Squared Error (Training)': rmse, 'Mean Absolute Percentage Error (Training)': mape, 'R2 Score (Training)': r2,
                                      'Root Mean Squared Error (WFV_OD)': rmse_wfod, 'Mean Absolute Percentage Error (WFV_OD)': mape_wfod, 'R2 Score (WFV_OD)': r2_wfod,
                                      'Root Mean Squared Error (WFV_Op)': rmse_wfp, 'Mean Absolute Percentage Error (WFV_Op)': mape_wfp, 'R2 Score (WFV_Op)': r2_wfp

    }])], ignore_index=True)

# Save evaluation metrics to Excel
evaluation_df.to_excel(f"{output_folder}/well_evaluation_metrics.xlsx", index=False)
# Out:
# Trial 5 Complete [00h 00m 17s]
# val_loss: 0.0029984634214391312
#
# Best val_loss So Far: 0.0012714134451622765
# Total elapsed time: 00h 02m 27s
# Epoch 1/100
# 44/44 - 2s - loss: 2400.3101 - mae: 7.0144 - val_loss: 0.0022 - val_mae: 0.0355 - 2s/epoch - 53ms/step
# Epoch 2/100
# 44/44 - 1s - loss: 0.0121 - mae: 0.0773 - val_loss: 0.0016 - val_mae: 0.0256 - 1s/epoch - 24ms/step
# Epoch 3/100
# 44/44 - 1s - loss: 0.0109 - mae: 0.0729 - val_loss: 0.0015 - val_mae: 0.0245 - 1s/epoch - 26ms/step
# Epoch 4/100
# 44/44 - 1s - loss: 0.0111 - mae: 0.0734 - val_loss: 0.0015 - val_mae: 0.0264 - 1s/epoch - 25ms/step
# Epoch 5/100
# 44/44 - 2s - loss: 0.0114 - mae: 0.0753 - val_loss: 0.0052 - val_mae: 0.0667 - 2s/epoch - 36ms/step
# Epoch 6/100
# 44/44 - 2s - loss: 0.0109 - mae: 0.0727 - val_loss: 0.0013 - val_mae: 0.0204 - 2s/epoch - 56ms/step
# Epoch 7/100
# 44/44 - 1s - loss: 0.0101 - mae: 0.0692 - val_loss: 0.0017 - val_mae: 0.0268 - 1s/epoch - 29ms/step
# Epoch 8/100
# 44/44 - 1s - loss: 0.0104 - mae: 0.0710 - val_loss: 0.0017 - val_mae: 0.0284 - 1s/epoch - 24ms/step
# Epoch 9/100
# 44/44 - 1s - loss: 0.0105 - mae: 0.0708 - val_loss: 0.0013 - val_mae: 0.0218 - 1s/epoch - 26ms/step
# Epoch 10/100
# 44/44 - 1s - loss: 0.0095 - mae: 0.0660 - val_loss: 0.0014 - val_mae: 0.0250 - 1s/epoch - 24ms/step
# Epoch 11/100
# 44/44 - 1s - loss: 0.0102 - mae: 0.0702 - val_loss: 0.0012 - val_mae: 0.0200 - 1s/epoch - 27ms/step
# Epoch 12/100
# 44/44 - 1s - loss: 0.0102 - mae: 0.0695 - val_loss: 0.0019 - val_mae: 0.0316 - 1s/epoch - 24ms/step
# Epoch 13/100
# 44/44 - 1s - loss: 0.0107 - mae: 0.0719 - val_loss: 0.0030 - val_mae: 0.0458 - 1s/epoch - 24ms/step
# Epoch 14/100
# 44/44 - 1s - loss: 0.0106 - mae: 0.0716 - val_loss: 0.0012 - val_mae: 0.0202 - 1s/epoch - 24ms/step
# Epoch 15/100
# 44/44 - 1s - loss: 0.0105 - mae: 0.0687 - val_loss: 0.0015 - val_mae: 0.0278 - 1s/epoch - 25ms/step
# Epoch 16/100
# 44/44 - 2s - loss: 0.0101 - mae: 0.0699 - val_loss: 0.0020 - val_mae: 0.0358 - 2s/epoch - 42ms/step
# Epoch 17/100
# 44/44 - 3s - loss: 0.0103 - mae: 0.0697 - val_loss: 0.0018 - val_mae: 0.0303 - 3s/epoch - 57ms/step
# Epoch 18/100
# 44/44 - 1s - loss: 0.0103 - mae: 0.0692 - val_loss: 0.0020 - val_mae: 0.0332 - 1s/epoch - 27ms/step
# Epoch 19/100
# 44/44 - 1s - loss: 0.0106 - mae: 0.0714 - val_loss: 0.0014 - val_mae: 0.0247 - 1s/epoch - 24ms/step
# Epoch 20/100
# 44/44 - 1s - loss: 0.0103 - mae: 0.0698 - val_loss: 0.0015 - val_mae: 0.0274 - 1s/epoch - 26ms/step
# Epoch 21/100
# 44/44 - 1s - loss: 0.0098 - mae: 0.0673 - val_loss: 0.0013 - val_mae: 0.0210 - 1s/epoch - 26ms/step
# Epoch 22/100
# 44/44 - 1s - loss: 0.0102 - mae: 0.0689 - val_loss: 0.0017 - val_mae: 0.0299 - 1s/epoch - 26ms/step
# Epoch 23/100
# 44/44 - 1s - loss: 0.0105 - mae: 0.0708 - val_loss: 0.0013 - val_mae: 0.0209 - 1s/epoch - 25ms/step
# Epoch 24/100
# 44/44 - 1s - loss: 0.0101 - mae: 0.0693 - val_loss: 0.0019 - val_mae: 0.0306 - 1s/epoch - 25ms/step
# Epoch 25/100
# 44/44 - 1s - loss: 0.0098 - mae: 0.0670 - val_loss: 0.0013 - val_mae: 0.0205 - 1s/epoch - 25ms/step
# Epoch 26/100
# 44/44 - 1s - loss: 0.0104 - mae: 0.0711 - val_loss: 0.0016 - val_mae: 0.0266 - 1s/epoch - 26ms/step
# Epoch 27/100
# 44/44 - 2s - loss: 0.0102 - mae: 0.0689 - val_loss: 0.0017 - val_mae: 0.0280 - 2s/epoch - 52ms/step
# Epoch 28/100
# 44/44 - 2s - loss: 0.0100 - mae: 0.0687 - val_loss: 0.0017 - val_mae: 0.0300 - 2s/epoch - 48ms/step
# Epoch 29/100
# 44/44 - 1s - loss: 0.0099 - mae: 0.0697 - val_loss: 0.0015 - val_mae: 0.0265 - 1s/epoch - 24ms/step
# Epoch 30/100
# 44/44 - 1s - loss: 0.0106 - mae: 0.0718 - val_loss: 0.0015 - val_mae: 0.0251 - 1s/epoch - 26ms/step
# Epoch 31/100
# 44/44 - 1s - loss: 0.0096 - mae: 0.0683 - val_loss: 0.0024 - val_mae: 0.0370 - 1s/epoch - 25ms/step
# Epoch 32/100
# 44/44 - 1s - loss: 0.0095 - mae: 0.0673 - val_loss: 0.0014 - val_mae: 0.0208 - 1s/epoch - 24ms/step
# Epoch 33/100
# 44/44 - 1s - loss: 0.0094 - mae: 0.0664 - val_loss: 0.0016 - val_mae: 0.0283 - 1s/epoch - 24ms/step
# Epoch 34/100
# 44/44 - 1s - loss: 0.0096 - mae: 0.0673 - val_loss: 0.0015 - val_mae: 0.0259 - 1s/epoch - 24ms/step
# Epoch 35/100
# 44/44 - 1s - loss: 0.0099 - mae: 0.0691 - val_loss: 0.0020 - val_mae: 0.0334 - 1s/epoch - 26ms/step
# Epoch 36/100
# 44/44 - 1s - loss: 0.0105 - mae: 0.0715 - val_loss: 0.0012 - val_mae: 0.0202 - 1s/epoch - 27ms/step
# Epoch 37/100
# 44/44 - 1s - loss: 0.0096 - mae: 0.0661 - val_loss: 0.0015 - val_mae: 0.0242 - 1s/epoch - 34ms/step
# Epoch 38/100
# 44/44 - 2s - loss: 0.0104 - mae: 0.0697 - val_loss: 0.0014 - val_mae: 0.0244 - 2s/epoch - 56ms/step
# Epoch 39/100
# 44/44 - 1s - loss: 0.0093 - mae: 0.0661 - val_loss: 0.0012 - val_mae: 0.0195 - 1s/epoch - 32ms/step
# Epoch 40/100
# 44/44 - 1s - loss: 0.0097 - mae: 0.0675 - val_loss: 0.0012 - val_mae: 0.0186 - 1s/epoch - 26ms/step
# Epoch 41/100
# 44/44 - 1s - loss: 0.0093 - mae: 0.0654 - val_loss: 0.0014 - val_mae: 0.0248 - 1s/epoch - 24ms/step
# Epoch 42/100
# 44/44 - 1s - loss: 0.0096 - mae: 0.0670 - val_loss: 0.0017 - val_mae: 0.0260 - 1s/epoch - 24ms/step
# Epoch 43/100
# 44/44 - 1s - loss: 0.0093 - mae: 0.0665 - val_loss: 0.0013 - val_mae: 0.0223 - 1s/epoch - 24ms/step
# Epoch 44/100
# 44/44 - 1s - loss: 0.0098 - mae: 0.0699 - val_loss: 0.0020 - val_mae: 0.0335 - 1s/epoch - 26ms/step
# Epoch 45/100
# 44/44 - 1s - loss: 0.0099 - mae: 0.0683 - val_loss: 0.0029 - val_mae: 0.0439 - 1s/epoch - 24ms/step
# Epoch 46/100
# 44/44 - 1s - loss: 0.0101 - mae: 0.0696 - val_loss: 0.0013 - val_mae: 0.0240 - 1s/epoch - 24ms/step
# Epoch 47/100
# 44/44 - 1s - loss: 0.0100 - mae: 0.0681 - val_loss: 0.0015 - val_mae: 0.0243 - 1s/epoch - 25ms/step
# Epoch 48/100
# 44/44 - 2s - loss: 0.0097 - mae: 0.0680 - val_loss: 0.0012 - val_mae: 0.0205 - 2s/epoch - 46ms/step
# Epoch 49/100
# 44/44 - 2s - loss: 0.0092 - mae: 0.0675 - val_loss: 0.0013 - val_mae: 0.0206 - 2s/epoch - 53ms/step
# Epoch 50/100
# 44/44 - 1s - loss: 0.0090 - mae: 0.0643 - val_loss: 0.0016 - val_mae: 0.0276 - 1s/epoch - 24ms/step
# Epoch 51/100
# 44/44 - 1s - loss: 0.0097 - mae: 0.0668 - val_loss: 0.0015 - val_mae: 0.0251 - 1s/epoch - 24ms/step
# Epoch 52/100
# 44/44 - 1s - loss: 0.0090 - mae: 0.0662 - val_loss: 0.0014 - val_mae: 0.0238 - 1s/epoch - 24ms/step
# Epoch 53/100
# 44/44 - 1s - loss: 0.0094 - mae: 0.0652 - val_loss: 0.0013 - val_mae: 0.0221 - 1s/epoch - 24ms/step
# Epoch 54/100
# 44/44 - 1s - loss: 0.0094 - mae: 0.0663 - val_loss: 0.0012 - val_mae: 0.0197 - 1s/epoch - 25ms/step
# Epoch 55/100
# 44/44 - 1s - loss: 0.0096 - mae: 0.0667 - val_loss: 0.0013 - val_mae: 0.0213 - 1s/epoch - 27ms/step
# Epoch 56/100
# 44/44 - 1s - loss: 0.0092 - mae: 0.0655 - val_loss: 0.0015 - val_mae: 0.0263 - 1s/epoch - 24ms/step
# Epoch 57/100
# 44/44 - 1s - loss: 0.0094 - mae: 0.0656 - val_loss: 0.0014 - val_mae: 0.0257 - 1s/epoch - 26ms/step
# Epoch 58/100
# 44/44 - 1s - loss: 0.0100 - mae: 0.0678 - val_loss: 0.0012 - val_mae: 0.0196 - 1s/epoch - 24ms/step
# Epoch 59/100
# 44/44 - 2s - loss: 0.0093 - mae: 0.0655 - val_loss: 0.0015 - val_mae: 0.0232 - 2s/epoch - 47ms/step
# Epoch 60/100
# 44/44 - 2s - loss: 0.0096 - mae: 0.0672 - val_loss: 0.0013 - val_mae: 0.0222 - 2s/epoch - 52ms/step
# Epoch 61/100
# 44/44 - 1s - loss: 0.0094 - mae: 0.0673 - val_loss: 0.0015 - val_mae: 0.0271 - 1s/epoch - 24ms/step
# Epoch 62/100
# 44/44 - 1s - loss: 0.0093 - mae: 0.0669 - val_loss: 0.0017 - val_mae: 0.0313 - 1s/epoch - 23ms/step
# Epoch 63/100
# 44/44 - 1s - loss: 0.0122 - mae: 0.0809 - val_loss: 0.0013 - val_mae: 0.0210 - 1s/epoch - 24ms/step
# Epoch 64/100
# 44/44 - 1s - loss: 0.0093 - mae: 0.0659 - val_loss: 0.0013 - val_mae: 0.0204 - 1s/epoch - 24ms/step
# Epoch 65/100
# 44/44 - 1s - loss: 0.0102 - mae: 0.0701 - val_loss: 0.0028 - val_mae: 0.0433 - 1s/epoch - 24ms/step
# Epoch 66/100
# 44/44 - 1s - loss: 0.0102 - mae: 0.0684 - val_loss: 0.0016 - val_mae: 0.0277 - 1s/epoch - 24ms/step
# Epoch 67/100
# 44/44 - 1s - loss: 0.0094 - mae: 0.0661 - val_loss: 0.0021 - val_mae: 0.0351 - 1s/epoch - 24ms/step
# Epoch 68/100
# 44/44 - 1s - loss: 0.0100 - mae: 0.0683 - val_loss: 0.0013 - val_mae: 0.0239 - 1s/epoch - 24ms/step
# Epoch 69/100
# 44/44 - 1s - loss: 0.0097 - mae: 0.0678 - val_loss: 0.0012 - val_mae: 0.0196 - 1s/epoch - 24ms/step
# Epoch 70/100
# 44/44 - 2s - loss: 0.0095 - mae: 0.0658 - val_loss: 0.0016 - val_mae: 0.0271 - 2s/epoch - 46ms/step
# Epoch 71/100
# 44/44 - 2s - loss: 0.0100 - mae: 0.0679 - val_loss: 0.0013 - val_mae: 0.0228 - 2s/epoch - 53ms/step
# Epoch 72/100
# 44/44 - 1s - loss: 0.0097 - mae: 0.0672 - val_loss: 0.0017 - val_mae: 0.0290 - 1s/epoch - 24ms/step
# Epoch 73/100
# 44/44 - 1s - loss: 0.0106 - mae: 0.0719 - val_loss: 0.0016 - val_mae: 0.0287 - 1s/epoch - 25ms/step
# Epoch 74/100
# 44/44 - 1s - loss: 0.0097 - mae: 0.0662 - val_loss: 0.0014 - val_mae: 0.0258 - 1s/epoch - 25ms/step
# Epoch 75/100
# 44/44 - 1s - loss: 0.0095 - mae: 0.0655 - val_loss: 0.0030 - val_mae: 0.0456 - 1s/epoch - 25ms/step
# Epoch 76/100
# 44/44 - 1s - loss: 0.0094 - mae: 0.0664 - val_loss: 0.0014 - val_mae: 0.0246 - 1s/epoch - 25ms/step
# Epoch 77/100
# 44/44 - 1s - loss: 0.0094 - mae: 0.0654 - val_loss: 0.0013 - val_mae: 0.0227 - 1s/epoch - 27ms/step
# Epoch 78/100
# 44/44 - 1s - loss: 0.0089 - mae: 0.0640 - val_loss: 0.0012 - val_mae: 0.0199 - 1s/epoch - 24ms/step
# Epoch 79/100
# 44/44 - 1s - loss: 0.0086 - mae: 0.0627 - val_loss: 0.0013 - val_mae: 0.0209 - 1s/epoch - 26ms/step
# Epoch 80/100
# 44/44 - 1s - loss: 0.0091 - mae: 0.0647 - val_loss: 0.0013 - val_mae: 0.0217 - 1s/epoch - 24ms/step
# Epoch 81/100
# 44/44 - 2s - loss: 0.0092 - mae: 0.0660 - val_loss: 0.0013 - val_mae: 0.0223 - 2s/epoch - 55ms/step
# Epoch 82/100
# 44/44 - 2s - loss: 0.0097 - mae: 0.0686 - val_loss: 0.0013 - val_mae: 0.0232 - 2s/epoch - 46ms/step
# Epoch 83/100
# 44/44 - 1s - loss: 0.0094 - mae: 0.0668 - val_loss: 0.0020 - val_mae: 0.0354 - 1s/epoch - 26ms/step
# Epoch 84/100
# 44/44 - 1s - loss: 0.0099 - mae: 0.0693 - val_loss: 0.0027 - val_mae: 0.0408 - 1s/epoch - 25ms/step
# Epoch 85/100
# 44/44 - 1s - loss: 0.0094 - mae: 0.0651 - val_loss: 0.0013 - val_mae: 0.0213 - 1s/epoch - 24ms/step
# Epoch 86/100
# 44/44 - 1s - loss: 0.0088 - mae: 0.0634 - val_loss: 0.0016 - val_mae: 0.0260 - 1s/epoch - 24ms/step
# Epoch 87/100
# 44/44 - 1s - loss: 0.0093 - mae: 0.0662 - val_loss: 0.0016 - val_mae: 0.0280 - 1s/epoch - 24ms/step
# Epoch 88/100
# 44/44 - 1s - loss: 0.0092 - mae: 0.0639 - val_loss: 0.0014 - val_mae: 0.0229 - 1s/epoch - 25ms/step
# Epoch 89/100
# 44/44 - 1s - loss: 0.0090 - mae: 0.0641 - val_loss: 0.0013 - val_mae: 0.0237 - 1s/epoch - 24ms/step
# Epoch 90/100
# 44/44 - 1s - loss: 0.0086 - mae: 0.0627 - val_loss: 0.0018 - val_mae: 0.0323 - 1s/epoch - 25ms/step
# Epoch 91/100
# 44/44 - 1s - loss: 0.0092 - mae: 0.0650 - val_loss: 0.0015 - val_mae: 0.0268 - 1s/epoch - 29ms/step
# Epoch 92/100
# 44/44 - 2s - loss: 0.0086 - mae: 0.0622 - val_loss: 0.0013 - val_mae: 0.0225 - 2s/epoch - 51ms/step
# Epoch 93/100
# 44/44 - 2s - loss: 0.0093 - mae: 0.0676 - val_loss: 0.0020 - val_mae: 0.0339 - 2s/epoch - 46ms/step
# Epoch 94/100
# 44/44 - 1s - loss: 0.0087 - mae: 0.0652 - val_loss: 0.0018 - val_mae: 0.0293 - 1s/epoch - 28ms/step
# Epoch 95/100
# 44/44 - 1s - loss: 0.0086 - mae: 0.0640 - val_loss: 0.0012 - val_mae: 0.0210 - 1s/epoch - 25ms/step
# Epoch 96/100
# 44/44 - 1s - loss: 0.0180 - mae: 0.0948 - val_loss: 0.0029 - val_mae: 0.0409 - 1s/epoch - 24ms/step
# Epoch 97/100
# 44/44 - 1s - loss: 0.0146 - mae: 0.0897 - val_loss: 0.0029 - val_mae: 0.0408 - 1s/epoch - 26ms/step
# Epoch 98/100
# 44/44 - 1s - loss: 0.0122 - mae: 0.0801 - val_loss: 0.0017 - val_mae: 0.0270 - 1s/epoch - 24ms/step
# Epoch 99/100
# 44/44 - 1s - loss: 0.0115 - mae: 0.0733 - val_loss: 0.0019 - val_mae: 0.0325 - 1s/epoch - 25ms/step
# Epoch 100/100
# 44/44 - 1s - loss: 0.0114 - mae: 0.0724 - val_loss: 0.0019 - val_mae: 0.0283 - 1s/epoch - 25ms/step
# Total Durasi Training Model: 130.73508763313293 Seconds
# Best Hyperparameters:
# units: 224
# activation: relu
# learning_rate: 0.01
# Model saved as RNN_best.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 16/16 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# <ipython-input-1-f0d03cb8cb87>:172: RuntimeWarning: divide by zero encountered in divide
#   train_ape = abs((y_train_actual - y_pred_train_actual) / y_train_actual) * 100
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# <ipython-input-1-f0d03cb8cb87>:192: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_actual.append(abs((actual_value - predicted_value) / actual_value) * 100)
# <ipython-input-1-f0d03cb8cb87>:192: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_actual.append(abs((actual_value - predicted_value) / actual_value) * 100)
# <ipython-input-1-f0d03cb8cb87>:192: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_actual.append(abs((actual_value - predicted_value) / actual_value) * 100)
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# <ipython-input-1-f0d03cb8cb87>:192: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_actual.append(abs((actual_value - predicted_value) / actual_value) * 100)
# <ipython-input-1-f0d03cb8cb87>:192: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_actual.append(abs((actual_value - predicted_value) / actual_value) * 100)
# <ipython-input-1-f0d03cb8cb87>:192: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_actual.append(abs((actual_value - predicted_value) / actual_value) * 100)
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# <ipython-input-1-f0d03cb8cb87>:192: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_actual.append(abs((actual_value - predicted_value) / actual_value) * 100)
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# <ipython-input-1-f0d03cb8cb87>:204: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_predicted.append(abs((y_test_actual[i] - predicted_value) / y_test_actual[i]) * 100)
# <ipython-input-1-f0d03cb8cb87>:204: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_predicted.append(abs((y_test_actual[i] - predicted_value) / y_test_actual[i]) * 100)
# <ipython-input-1-f0d03cb8cb87>:204: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_predicted.append(abs((y_test_actual[i] - predicted_value) / y_test_actual[i]) * 100)
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# <ipython-input-1-f0d03cb8cb87>:204: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_predicted.append(abs((y_test_actual[i] - predicted_value) / y_test_actual[i]) * 100)
# <ipython-input-1-f0d03cb8cb87>:204: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_predicted.append(abs((y_test_actual[i] - predicted_value) / y_test_actual[i]) * 100)
# <ipython-input-1-f0d03cb8cb87>:204: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_predicted.append(abs((y_test_actual[i] - predicted_value) / y_test_actual[i]) * 100)
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# <ipython-input-1-f0d03cb8cb87>:204: RuntimeWarning: divide by zero encountered in scalar divide
#   wfv_ape_predicted.append(abs((y_test_actual[i] - predicted_value) / y_test_actual[i]) * 100)
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 11/11 [==============================] - 0s 14ms/step
# 3/3 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 5/5 [==============================] - 0s 7ms/step
# ...
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 14/14 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 9ms/step
# <ipython-input-1-f0d03cb8cb87>:172: RuntimeWarning: divide by zero encountered in divide
#   train_ape = abs((y_train_actual - y_pred_train_actual) / y_train_actual) * 100
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# Ensure plots directory exists
plots_dir = "RNN_blind"
if not os.path.exists(plots_dir):
    os.makedirs(plots_dir)

# Load the trained model
best_model = load_model("RNN_best.h5")

# Load blind test data for one well
blind_test_file = '65.xlsx'
well_name = os.path.splitext(blind_test_file)[0]  # Extract the well name from the file name
blind_test_df = pd.read_excel(blind_test_file)
blind_test_df['VOLUME_DATE'] = pd.to_datetime(blind_test_df['VOLUME_DATE'])
blind_test_df['VOLUME_DATE'] = blind_test_df['VOLUME_DATE'].dt.date
blind_test_df = blind_test_df.groupby('VOLUME_DATE', as_index=False).agg({'ALLOC_OIL_AWO': 'mean'})
blind_test_df = blind_test_df.set_index('VOLUME_DATE')

# Function to create sequences
def create_sequences(data, seq_length):
    sequences = []
    targets = []

    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        target = data[i + seq_length]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# Extract and normalize data for blind test
blind_test_prod = blind_test_df['ALLOC_OIL_AWO'].values.reshape(-1, 1)
scaler = MinMaxScaler()
blind_test_data_normalized = scaler.fit_transform(blind_test_prod)

# Create sequences for blind test
sequence_length = 30
X, y = create_sequences(blind_test_data_normalized, sequence_length)

# Make predictions using the loaded model
blind_test_predictions = best_model.predict(X)

# Invert the normalization for better interpretation of predictions
blind_test_predictions_inv = scaler.inverse_transform(blind_test_predictions)
y_blind_test_inv = scaler.inverse_transform(y.reshape(-1, 1))

# Calculate absolute error
absolute_errors = np.abs(y_blind_test_inv - blind_test_predictions_inv)

# Calculate absolute percentage error
ape = np.abs((y_blind_test_inv - blind_test_predictions_inv) / y_blind_test_inv) * 100

# Evaluate and visualize the predictions for one well
total_actual = np.sum(y_blind_test_inv)
total_pred = np.sum(blind_test_predictions_inv)
# print(f'Actual: {total_actual:.2f} Predicted: {total_pred:.2f}')

# mae = mean_absolute_error(y_blind_test_inv, blind_test_predictions_inv)
# print(f'Mean Absolute Error: {mae:.2f}')

# rmse = np.sqrt(mean_squared_error(y_blind_test_inv, blind_test_predictions_inv))
# print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

# mape = mean_absolute_percentage_error(y_blind_test_inv, blind_test_predictions_inv)
# print(f'Mean Absolute Percentage Error (MAPE): {mape * 100:.2f}%')

# accuracy = 1 - mape
# print(f'Accuracy: {accuracy * 100:.2f}%')

# r2 = r2_score(y_blind_test_inv, blind_test_predictions_inv)
# print(f'R2 Score: {r2:.2f}')

# # Plot Actual vs. Predicted
# plt.figure(figsize=(18, 6))
# plt.plot(blind_test_df.index, blind_test_df['ALLOC_OIL_AWO'], label='Historical')
# plt.plot(blind_test_df.index[-len(blind_test_predictions_inv):], blind_test_predictions_inv, label='Predicted')
# plt.title(f'Actual vs. Predicted for Well {well_name}')
# plt.xlabel('Date')
# plt.ylabel('Production Volume')
# plt.legend()
# plt.savefig(os.path.join(plots_dir, f'actual_vs_predicted_{well_name}.png'))
# plt.show()

# # Plot absolute error
# plt.figure(figsize=(18, 6))
# plt.plot(blind_test_df.index[-len(absolute_errors):], absolute_errors, label='Absolute Error')
# plt.title(f'Absolute Error Over Time for Well {well_name}')
# plt.xlabel('Date')
# plt.ylabel('Absolute Error')
# plt.legend()
# plt.savefig(os.path.join(plots_dir, f'absolute_error_{well_name}.png'))
# plt.show()

# # Combine actual and predicted values into a DataFrame
# df_combined = pd.DataFrame({'Actual': y_blind_test_inv.flatten(), 'Predicted': blind_test_predictions_inv.flatten()}, index=blind_test_df.index[-len(y_blind_test_inv):])
# print(df_combined)

# # Plot absolute percentage error with 10% error line and actual data
# plt.figure(figsize=(18, 6))
# plt.plot(blind_test_df.index[-len(ape):], ape, label='Absolute Percentage Error')
# plt.axhline(y=10, color='r', linestyle='--', label='10% Error Line')
# plt.title(f'Absolute Percentage Error Over Time for Well {well_name}')
# plt.xlabel('Date')
# plt.ylabel('Absolute Percentage Error (%)')
# plt.legend()
# plt.savefig(os.path.join(plots_dir, f'ape_over_time_{well_name}.png'))
# plt.show()

# Walk-forward validation over actual data
actual_predictions = []

for i in range(sequence_length, len(blind_test_data_normalized)):
    # Use actual data up to the current point to predict the next point
    seq = blind_test_data_normalized[i-sequence_length:i].reshape(1, sequence_length, 1)
    pred = best_model.predict(seq)
    actual_predictions.append(pred[0][0])

# Invert normalization
actual_predictions_inv = scaler.inverse_transform(np.array(actual_predictions).reshape(-1, 1))
actual_targets_inv = scaler.inverse_transform(blind_test_data_normalized[sequence_length:].reshape(-1, 1))

# Calculate metrics for actual data predictions
mae_actual = mean_absolute_error(actual_targets_inv, actual_predictions_inv)
rmse_actual = np.sqrt(mean_squared_error(actual_targets_inv, actual_predictions_inv))
mape_actual = mean_absolute_percentage_error(actual_targets_inv, actual_predictions_inv)
r2_actual = r2_score(actual_targets_inv, actual_predictions_inv)

print(f'Actual Data - MAE: {mae_actual:.2f}, RMSE: {rmse_actual:.2f}, MAPE: {mape_actual * 100:.2f}%, R2: {r2_actual}')

predicted_predictions = []

# Initialize with the first sequence of actual data
predicted_seq = blind_test_data_normalized[:sequence_length].reshape(1, sequence_length, 1)

# Collect predictions iteratively
for i in range(sequence_length, len(blind_test_data_normalized)):
    pred = best_model.predict(predicted_seq)
    predicted_predictions.append(pred[0][0])
    # Update the sequence by removing the first value and appending the predicted value
    predicted_seq = np.append(predicted_seq[:, :1, :], [[pred[0]]], axis=1)

# Invert normalization
predicted_predictions_inv = scaler.inverse_transform(np.array(predicted_predictions).reshape(-1, 1))
predicted_targets_inv = scaler.inverse_transform(blind_test_data_normalized[sequence_length:].reshape(-1, 1))

# Calculate metrics for predicted data predictions
mae_predicted = mean_absolute_error(predicted_targets_inv, predicted_predictions_inv)
rmse_predicted = np.sqrt(mean_squared_error(predicted_targets_inv, predicted_predictions_inv))
mape_predicted = mean_absolute_percentage_error(predicted_targets_inv, predicted_predictions_inv)
r2_predicted = r2_score(predicted_targets_inv, predicted_predictions_inv)

print(f'Predicted Data - MAE: {mae_predicted:.2f}, RMSE: {rmse_predicted:.2f}, MAPE: {mape_predicted * 100:.2f}%, R2: {r2_predicted}')

# Calculate absolute percentage error for walk-forward validation
ape_actual_wfv = np.abs((actual_targets_inv - actual_predictions_inv) / actual_targets_inv) * 100
ape_predicted_wfv = np.abs((predicted_targets_inv - predicted_predictions_inv) / predicted_targets_inv) * 100

# Plot Actual vs. Predicted for Walk-forward Validation
plt.figure(figsize=(18, 6))
plt.plot(blind_test_df.index, blind_test_df['ALLOC_OIL_AWO'], label='Actual')
plt.plot(blind_test_df.index[-len(actual_predictions_inv):], actual_predictions_inv, label='WFV (Actual Data)')
plt.plot(blind_test_df.index[-len(predicted_predictions_inv):], predicted_predictions_inv, label='WFV (Predicted Data)')
plt.title(f'RNN Blind Test Well X-{well_name}')
plt.xlabel('Date')
plt.ylabel('Production Volume')
plt.legend()
plt.savefig(os.path.join(plots_dir, f'walk_forward_validation_{well_name}.png'))
plt.show()

# Plot absolute percentage error for walk-forward validation over actual and predicted data
plt.figure(figsize=(18, 6))
plt.plot(blind_test_df.index[-len(ape_actual_wfv):], ape_actual_wfv, label='APE (WFV Actual Data)')
plt.plot(blind_test_df.index[-len(ape_predicted_wfv):], ape_predicted_wfv, label='APE (WFV Predicted Data)')
plt.axhline(y=10, color='r', linestyle='--', label='10% Error Line')
plt.title(f'RNN Absolute Percentage Error Over Time (Walk-forward Validation) for Well X-{well_name}')
plt.xlabel('Date')
plt.ylabel('Absolute Percentage Error (%)')
plt.legend()
plt.savefig(os.path.join(plots_dir, f'ape_wfv_{well_name}.png'))
plt.show()

# Save evaluation metrics to Excel
evaluation_metrics = pd.DataFrame({
    'Metric': ['MAE', 'RMSE', 'MAPE', 'R2'],
    'WFV Actual Data': [mae_actual, rmse_actual, mape_actual, r2_actual],
    'WFV Predicted Data': [mae_predicted, rmse_predicted, mape_predicted, r2_predicted]
})

evaluation_metrics.to_excel(f"{plots_dir}/wfv_evaluation_metrics_{well_name}.xlsx", index=False)

print(evaluation_metrics)
# Out:
# 19/19 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# Actual Data - MAE: 10.19, RMSE: 15.22, MAPE: 8.95%, R2: 0.8677705637680386
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# Predicted Data - MAE: 102.63, RMSE: 110.84, MAPE: 89.82%, R2: -6.0101604683979675
#   Metric  WFV Actual Data  WFV Predicted Data
# 0    MAE        10.193239          102.628990
# 1   RMSE        15.223253          110.842770
# 2   MAPE         0.089512            0.898158
# 3     R2         0.867771           -6.010160

# %%
# !zip -r /content/RNN_run.zip /content/RNN_run/
# Out:
#   adding: content/RNN_run/ (stored 0%)
#   adding: content/RNN_run/X-265_ape_plot.png (deflated 11%)
#   adding: content/RNN_run/X-341_prediction_plot.png (deflated 9%)
#   adding: content/RNN_run/X-197_prediction_plot.png (deflated 10%)
#   adding: content/RNN_run/X-197_ape_plot.png (deflated 9%)
#   adding: content/RNN_run/X-218_ape_plot.png (deflated 10%)
#   adding: content/RNN_run/well_evaluation_metrics.xlsx (deflated 9%)
#   adding: content/RNN_run/X-218_prediction_plot.png (deflated 9%)
#   adding: content/RNN_run/X-269_prediction_plot.png (deflated 9%)
#   adding: content/RNN_run/X-269_ape_plot.png (deflated 9%)
#   adding: content/RNN_run/X-341_ape_plot.png (deflated 12%)
#   adding: content/RNN_run/X-57_ape_plot.png (deflated 10%)
#   adding: content/RNN_run/X-265_prediction_plot.png (deflated 8%)
#   adding: content/RNN_run/X-57_prediction_plot.png (deflated 8%)

# %%
# !zip -r /content/RNN_blind.zip /content/RNN_blind/
# Out:
#   adding: content/RNN_blind/ (stored 0%)
#   adding: content/RNN_blind/ape_wfv_4.png (deflated 7%)
#   adding: content/RNN_blind/ape_wfv_65.png (deflated 7%)
#   adding: content/RNN_blind/wfv_evaluation_metrics_65.xlsx (deflated 11%)
#   adding: content/RNN_blind/.ipynb_checkpoints/ (stored 0%)
#   adding: content/RNN_blind/walk_forward_validation_65.png (deflated 5%)
#   adding: content/RNN_blind/wfv_evaluation_metrics_4.xlsx (deflated 11%)
#   adding: content/RNN_blind/walk_forward_validation_4.png (deflated 5%)

# %%
# !zip -r /content/keras_tuner_logs.zip /content/keras_tuner_logs/
# Out:
#   adding: content/keras_tuner_logs/ (stored 0%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/ (stored 0%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_3/ (stored 0%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_3/trial.json (deflated 62%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_3/checkpoint.data-00000-of-00001 (deflated 8%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_3/checkpoint (deflated 48%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_3/checkpoint.index (deflated 57%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_1/ (stored 0%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_1/trial.json (deflated 62%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_1/checkpoint.data-00000-of-00001 (deflated 8%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_1/checkpoint (deflated 48%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_1/checkpoint.index (deflated 57%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/oracle.json (deflated 61%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_4/ (stored 0%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_4/trial.json (deflated 62%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_4/checkpoint.data-00000-of-00001 (deflated 9%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_4/checkpoint (deflated 48%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_4/checkpoint.index (deflated 57%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/tuner0.json (stored 0%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_0/ (stored 0%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_0/trial.json (deflated 63%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_0/checkpoint.data-00000-of-00001 (deflated 11%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_0/checkpoint (deflated 48%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_0/checkpoint.index (deflated 57%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_2/ (stored 0%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_2/trial.json (deflated 62%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_2/checkpoint.data-00000-of-00001 (deflated 8%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_2/checkpoint (deflated 48%)
#   adding: content/keras_tuner_logs/oil_production_forecasting/trial_2/checkpoint.index (deflated 57%)

# %%
import os
import pandas as pd
import numpy as np
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from kerastuner.tuners import RandomSearch
import matplotlib.pyplot as plt

# List of Excel files for multiple wells
well_files = ['57.xlsx', '197.xlsx', '218.xlsx', '265.xlsx', '269.xlsx', '341.xlsx']

# Combine data from multiple wells
combined_df = pd.DataFrame()

for file in well_files:
    df = pd.read_excel(file)
    df['VOLUME_DATE'] = pd.to_datetime(df['VOLUME_DATE'])
    df = df.set_index('VOLUME_DATE')

    # Select only the 'ALLOC_OIL_AWO' column
    df = df[['ALLOC_OIL_AWO']]

    # Aggregate data by mean
    aggregated_df = df.resample('D').mean()  # Resample data daily and calculate mean

    # Add a column for well label with "X-" prefix
    well_label = "X-" + file.split('.')[0]  # Add "X-" prefix to well label
    aggregated_df['WELL_LABEL'] = well_label

    # Combine the aggregated data
    combined_df = pd.concat([combined_df, aggregated_df], axis=0)

# Drop NaN values
combined_df = combined_df.dropna()

def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        target = data[i + seq_length]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Initialize lists to hold sequences, targets, and original data
X_train_list = []
y_train_list = []
X_test_list = []
y_test_list = []
train_dates_list = []
test_dates_list = []
scalers = {}
train_dfs = {}
test_dfs = {}

# Group by WELL_LABEL and create sequences for each group
sequence_length = 30
for label, group in combined_df.groupby('WELL_LABEL'):
    prod = group['ALLOC_OIL_AWO'].values.reshape(-1, 1)
    dates = group.index[sequence_length:]  # Skip the initial sequence length
    scaler = MinMaxScaler()
    production_data_normalized = scaler.fit_transform(prod)
    X, y = create_sequences(production_data_normalized, sequence_length)

    if len(X) > 0 and len(y) > 0:
        split = int(0.8 * len(X))
        X_train_temp, X_test_temp = X[:split], X[split:]
        y_train_temp, y_test_temp = y[:split], y[split:]
        dates_train, dates_test = dates[:split], dates[split:]

        X_train_list.append(X_train_temp)
        y_train_list.append(y_train_temp)
        X_test_list.append(X_test_temp)
        y_test_list.append(y_test_temp)
        train_dates_list.append(dates_train)
        test_dates_list.append(dates_test)
        scalers[label] = scaler

        # Save the original dataframes for training and testing
        train_dfs[label] = group.iloc[:len(dates_train)]
        test_dfs[label] = group.iloc[len(dates_train):]

# Combine all wells data into single arrays
X_train = np.concatenate(X_train_list, axis=0)
y_train = np.concatenate(y_train_list, axis=0)
X_test = np.concatenate(X_test_list, axis=0)
y_test = np.concatenate(y_test_list, axis=0)

# Display shapes of the final arrays
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")

# Print the describe for each well's training and testing data
for label in train_dfs:
    print(f"Training data description for well {label}:")
    print(train_dfs[label].describe())
    print("\nTesting data description for well {label}:")
    print(test_dfs[label].describe())
    print("\n")
# Out:
# X_train shape: (2189, 30, 1)
# y_train shape: (2189, 1)
# X_test shape: (551, 30, 1)
# y_test shape: (551, 1)
# Training data description for well X-197:
#        ALLOC_OIL_AWO
# count     421.000000
# mean       74.653171
# std        61.023508
# min        11.940000
# 25%        21.080000
# 50%        32.330000
# 75%       141.820000
# max       188.760000
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     136.000000
# mean       26.166912
# std         7.283494
# min         8.980000
# 25%        17.280000
# 50%        29.670000
# 75%        31.552500
# max        39.000000
#
#
# Training data description for well X-218:
#        ALLOC_OIL_AWO
# count     508.000000
# mean       40.291781
# std        23.860057
# min         0.000000
# 25%        19.782500
# 50%        28.160000
# 75%        66.472500
# max        97.590000
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     158.000000
# mean       25.877089
# std         8.518997
# min         0.000000
# 25%        23.735000
# 50%        25.045000
# 75%        27.055000
# max        49.680000
#
#
# Training data description for well X-265:
#        ALLOC_OIL_AWO
# count     328.000000
# mean      100.597053
# std        17.232694
# min         0.000000
# 25%        93.415000
# 50%       102.785000
# 75%       110.687500
# max       153.860000
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     113.000000
# mean       81.755708
# std         8.312381
# min        52.540000
# 25%        76.970000
# 50%        81.680000
# 75%        85.290000
# max       105.940000
#
#
# Training data description for well X-269:
#        ALLOC_OIL_AWO
# count     160.000000
# mean      114.585833
# std        30.208567
# min        21.860000
# 25%        98.100000
# 50%       117.120000
# 75%       125.469167
# max       220.943333
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count      70.000000
# mean      127.077476
# std         8.810168
# min        82.220000
# 25%       123.562500
# 50%       128.580000
# 75%       131.560000
# max       154.560000
#
#
# Training data description for well X-341:
#        ALLOC_OIL_AWO
# count     334.000000
# mean      176.236262
# std        56.544779
# min         9.270000
# 25%       139.232500
# 50%       177.110000
# 75%       214.847500
# max       331.410000
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     114.000000
# mean       90.513991
# std        21.941058
# min        47.240000
# 25%        69.390000
# 50%        96.070000
# 75%       107.840000
# max       157.120000
#
#
# Training data description for well X-57:
#        ALLOC_OIL_AWO
# count     438.000000
# mean       59.797557
# std        10.729115
# min         0.000000
# 25%        54.725000
# 50%        60.060000
# 75%        66.660000
# max        99.460000
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     140.000000
# mean       39.212964
# std        10.025835
# min        26.600000
# 25%        31.337500
# 50%        33.945000
# 75%        47.605000
# max        68.140000

# %%
import os
import pandas as pd
import numpy as np
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from kerastuner.tuners import RandomSearch
import matplotlib.pyplot as plt

# List of Excel files for multiple wells
well_files = ['57.xlsx', '197.xlsx', '218.xlsx', '265.xlsx', '269.xlsx', '341.xlsx']

# Combine data from multiple wells
combined_df = pd.DataFrame()

for file in well_files:
    df = pd.read_excel(file)
    df['VOLUME_DATE'] = pd.to_datetime(df['VOLUME_DATE'])
    df = df.set_index('VOLUME_DATE')

    # Select only the 'ALLOC_OIL_AWO' column
    df = df[['ALLOC_OIL_AWO']]

    # Aggregate data by mean
    aggregated_df = df.resample('D').mean()  # Resample data daily and calculate mean

    # Add a column for well label with "X-" prefix
    well_label = "X-" + file.split('.')[0]  # Add "X-" prefix to well label
    aggregated_df['WELL_LABEL'] = well_label

    # Combine the aggregated data
    combined_df = pd.concat([combined_df, aggregated_df], axis=0)

# Drop NaN values
combined_df = combined_df.dropna()

def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        target = data[i + seq_length]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Initialize lists to hold sequences, targets, and original data
X_train_list = []
y_train_list = []
X_test_list = []
y_test_list = []
train_dates_list = []
test_dates_list = []
scalers = {}
train_dfs = {}
test_dfs = {}
train_date_ranges = {}
test_date_ranges = {}

# Group by WELL_LABEL and create sequences for each group
sequence_length = 30
for label, group in combined_df.groupby('WELL_LABEL'):
    prod = group['ALLOC_OIL_AWO'].values.reshape(-1, 1)
    dates = group.index[sequence_length:]  # Skip the initial sequence length
    scaler = MinMaxScaler()
    production_data_normalized = scaler.fit_transform(prod)
    X, y = create_sequences(production_data_normalized, sequence_length)

    if len(X) > 0 and len(y) > 0:
        split = int(0.8 * len(X))
        X_train_temp, X_test_temp = X[:split], X[split:]
        y_train_temp, y_test_temp = y[:split], y[split:]
        dates_train, dates_test = dates[:split], dates[split:]

        X_train_list.append(X_train_temp)
        y_train_list.append(y_train_temp)
        X_test_list.append(X_test_temp)
        y_test_list.append(y_test_temp)
        train_dates_list.append(dates_train)
        test_dates_list.append(dates_test)
        scalers[label] = scaler

        # Save the original dataframes for training and testing
        train_dfs[label] = group.iloc[:len(dates_train)]
        test_dfs[label] = group.iloc[len(dates_train):]

        # Save the date ranges
        train_date_ranges[label] = (dates_train[0], dates_train[-1])
        test_date_ranges[label] = (dates_test[0], dates_test[-1])

# Combine all wells data into single arrays
X_train = np.concatenate(X_train_list, axis=0)
y_train = np.concatenate(y_train_list, axis=0)
X_test = np.concatenate(X_test_list, axis=0)
y_test = np.concatenate(y_test_list, axis=0)

# Display shapes of the final arrays
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")

# Print the describe and date ranges for each well's training and testing data
for label in train_dfs:
    print(f"Training data description for well {label}:")
    print(train_dfs[label].describe())
    print(f"Training date range: {train_date_ranges[label][0]} to {train_date_ranges[label][1]}")
    print("\nTesting data description for well {label}:")
    print(test_dfs[label].describe())
    print(f"Testing date range: {test_date_ranges[label][0]} to {test_date_ranges[label][1]}")
    print("\n")
# Out:
# X_train shape: (2189, 30, 1)
# y_train shape: (2189, 1)
# X_test shape: (551, 30, 1)
# y_test shape: (551, 1)
# Training data description for well X-197:
#        ALLOC_OIL_AWO
# count     421.000000
# mean       74.653171
# std        61.023508
# min        11.940000
# 25%        21.080000
# 50%        32.330000
# 75%       141.820000
# max       188.760000
# Training date range: 2022-07-26 00:00:00 to 2023-09-19 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     136.000000
# mean       26.166912
# std         7.283494
# min         8.980000
# 25%        17.280000
# 50%        29.670000
# 75%        31.552500
# max        39.000000
# Testing date range: 2023-09-20 00:00:00 to 2024-01-08 00:00:00
#
#
# Training data description for well X-218:
#        ALLOC_OIL_AWO
# count     508.000000
# mean       40.291781
# std        23.860057
# min         0.000000
# 25%        19.782500
# 50%        28.160000
# 75%        66.472500
# max        97.590000
# Training date range: 2022-04-15 00:00:00 to 2023-09-04 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     158.000000
# mean       25.877089
# std         8.518997
# min         0.000000
# 25%        23.735000
# 50%        25.045000
# 75%        27.055000
# max        49.680000
# Testing date range: 2023-09-05 00:00:00 to 2024-01-22 00:00:00
#
#
# Training data description for well X-265:
#        ALLOC_OIL_AWO
# count     328.000000
# mean      100.597053
# std        17.232694
# min         0.000000
# 25%        93.415000
# 50%       102.785000
# 75%       110.687500
# max       153.860000
# Training date range: 2022-11-24 00:00:00 to 2023-10-17 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     113.000000
# mean       81.755708
# std         8.312381
# min        52.540000
# 25%        76.970000
# 50%        81.680000
# 75%        85.290000
# max       105.940000
# Testing date range: 2023-10-18 00:00:00 to 2024-01-08 00:00:00
#
#
# Training data description for well X-269:
#        ALLOC_OIL_AWO
# count     160.000000
# mean      114.585833
# std        30.208567
# min        21.860000
# 25%        98.100000
# 50%       117.120000
# 75%       125.469167
# max       220.943333
# Training date range: 2023-06-24 00:00:00 to 2023-11-30 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count      70.000000
# mean      127.077476
# std         8.810168
# min        82.220000
# 25%       123.562500
# 50%       128.580000
# 75%       131.560000
# max       154.560000
# Testing date range: 2023-12-01 00:00:00 to 2024-01-09 00:00:00
#
#
# Training data description for well X-341:
#        ALLOC_OIL_AWO
# count     334.000000
# mean      176.236262
# std        56.544779
# min         9.270000
# 25%       139.232500
# 50%       177.110000
# 75%       214.847500
# max       331.410000
# Training date range: 2022-11-17 00:00:00 to 2023-10-16 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     114.000000
# mean       90.513991
# std        21.941058
# min        47.240000
# 25%        69.390000
# 50%        96.070000
# 75%       107.840000
# max       157.120000
# Testing date range: 2023-10-17 00:00:00 to 2024-01-08 00:00:00
#
#
# Training data description for well X-57:
#        ALLOC_OIL_AWO
# count     438.000000
# mean       59.797557
# std        10.729115
# min         0.000000
# 25%        54.725000
# 50%        60.060000
# 75%        66.660000
# max        99.460000
# Training date range: 2022-06-06 00:00:00 to 2023-08-17 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     140.000000
# mean       39.212964
# std        10.025835
# min        26.600000
# 25%        31.337500
# 50%        33.945000
# 75%        47.605000
# max        68.140000
# Testing date range: 2023-08-18 00:00:00 to 2023-12-05 00:00:00

# %%
import os
import pandas as pd
import numpy as np
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from kerastuner.tuners import RandomSearch
import matplotlib.pyplot as plt

# List of Excel files for multiple wells
well_files = ['57.xlsx', '197.xlsx', '218.xlsx', '265.xlsx', '269.xlsx', '341.xlsx']

# Combine data from multiple wells
combined_df = pd.DataFrame()

for file in well_files:
    df = pd.read_excel(file)
    df['VOLUME_DATE'] = pd.to_datetime(df['VOLUME_DATE'])
    df = df.set_index('VOLUME_DATE')

    # Select only the 'ALLOC_OIL_AWO' column
    df = df[['ALLOC_OIL_AWO']]

    # Aggregate data by mean
    aggregated_df = df.resample('D').mean()  # Resample data daily and calculate mean

    # Add a column for well label with "X-" prefix
    well_label = "X-" + file.split('.')[0]  # Add "X-" prefix to well label
    aggregated_df['WELL_LABEL'] = well_label

    # Combine the aggregated data
    combined_df = pd.concat([combined_df, aggregated_df], axis=0)

# Drop NaN values
combined_df = combined_df.dropna()

def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        target = data[i + seq_length]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Initialize lists to hold sequences, targets, and original data
X_train_list = []
y_train_list = []
X_test_list = []
y_test_list = []
train_dates_list = []
test_dates_list = []
scalers = {}
train_dfs = {}
test_dfs = {}
train_date_ranges = {}
test_date_ranges = {}

# Group by WELL_LABEL and create sequences for each group
sequence_length = 30
for label, group in combined_df.groupby('WELL_LABEL'):
    prod = group['ALLOC_OIL_AWO'].values.reshape(-1, 1)
    dates = group.index[sequence_length:]  # Skip the initial sequence length
    scaler = MinMaxScaler()
    production_data_normalized = scaler.fit_transform(prod)
    X, y = create_sequences(production_data_normalized, sequence_length)

    if len(X) > 0 and len(y) > 0:
        split = int(0.8 * len(X))
        X_train_temp, X_test_temp = X[:split], X[split:]
        y_train_temp, y_test_temp = y[:split], y[split:]
        dates_train, dates_test = dates[:split], dates[split:]

        X_train_list.append(X_train_temp)
        y_train_list.append(y_train_temp)
        X_test_list.append(X_test_temp)
        y_test_list.append(y_test_temp)
        train_dates_list.append(dates_train)
        test_dates_list.append(dates_test)
        scalers[label] = scaler

        # Save the original dataframes for training and testing
        train_dfs[label] = group.iloc[:len(dates_train)]
        test_dfs[label] = group.iloc[len(dates_train):]

        # Save the date ranges
        train_date_ranges[label] = (dates_train[0], dates_train[-1])
        test_date_ranges[label] = (dates_test[0], dates_test[-1])

# Combine all wells data into single arrays
X_train = np.concatenate(X_train_list, axis=0)
y_train = np.concatenate(y_train_list, axis=0)
X_test = np.concatenate(X_test_list, axis=0)
y_test = np.concatenate(y_test_list, axis=0)

# Display shapes of the final arrays
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")

# Print the describe and date ranges for each well's training and testing data
for label in train_dfs:
    print(f"Training data description for well {label}:")
    print(train_dfs[label].describe())
    print(f"Training date range: {train_date_ranges[label][0]} to {train_date_ranges[label][1]}")
    print("\nTesting data description for well {label}:")
    print(test_dfs[label].describe())
    print(f"Testing date range: {test_date_ranges[label][0]} to {test_date_ranges[label][1]}")
    print("\n")

    # Save to Excel
    with pd.ExcelWriter(f'{label}_data.xlsx') as writer:
        train_dfs[label].to_excel(writer, sheet_name='Train')
        test_dfs[label].to_excel(writer, sheet_name='Test')
        print(f"Data for well {label} has been saved to {label}_data.xlsx")
# Out:
# X_train shape: (2189, 30, 1)
# y_train shape: (2189, 1)
# X_test shape: (551, 30, 1)
# y_test shape: (551, 1)
# Training data description for well X-197:
#        ALLOC_OIL_AWO
# count     421.000000
# mean       74.653171
# std        61.023508
# min        11.940000
# 25%        21.080000
# 50%        32.330000
# 75%       141.820000
# max       188.760000
# Training date range: 2022-07-26 00:00:00 to 2023-09-19 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     136.000000
# mean       26.166912
# std         7.283494
# min         8.980000
# 25%        17.280000
# 50%        29.670000
# 75%        31.552500
# max        39.000000
# Testing date range: 2023-09-20 00:00:00 to 2024-01-08 00:00:00
#
#
# Data for well X-197 has been saved to X-197_data.xlsx
# Training data description for well X-218:
#        ALLOC_OIL_AWO
# count     508.000000
# mean       40.291781
# std        23.860057
# min         0.000000
# 25%        19.782500
# 50%        28.160000
# 75%        66.472500
# max        97.590000
# Training date range: 2022-04-15 00:00:00 to 2023-09-04 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     158.000000
# mean       25.877089
# std         8.518997
# min         0.000000
# 25%        23.735000
# 50%        25.045000
# 75%        27.055000
# max        49.680000
# Testing date range: 2023-09-05 00:00:00 to 2024-01-22 00:00:00
#
#
# Data for well X-218 has been saved to X-218_data.xlsx
# Training data description for well X-265:
#        ALLOC_OIL_AWO
# count     328.000000
# mean      100.597053
# std        17.232694
# min         0.000000
# 25%        93.415000
# 50%       102.785000
# 75%       110.687500
# max       153.860000
# Training date range: 2022-11-24 00:00:00 to 2023-10-17 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     113.000000
# mean       81.755708
# std         8.312381
# min        52.540000
# 25%        76.970000
# 50%        81.680000
# 75%        85.290000
# max       105.940000
# Testing date range: 2023-10-18 00:00:00 to 2024-01-08 00:00:00
#
#
# Data for well X-265 has been saved to X-265_data.xlsx
# Training data description for well X-269:
#        ALLOC_OIL_AWO
# count     160.000000
# mean      114.585833
# std        30.208567
# min        21.860000
# 25%        98.100000
# 50%       117.120000
# 75%       125.469167
# max       220.943333
# Training date range: 2023-06-24 00:00:00 to 2023-11-30 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count      70.000000
# mean      127.077476
# std         8.810168
# min        82.220000
# 25%       123.562500
# 50%       128.580000
# 75%       131.560000
# max       154.560000
# Testing date range: 2023-12-01 00:00:00 to 2024-01-09 00:00:00
#
#
# Data for well X-269 has been saved to X-269_data.xlsx
# Training data description for well X-341:
#        ALLOC_OIL_AWO
# count     334.000000
# mean      176.236262
# std        56.544779
# min         9.270000
# 25%       139.232500
# 50%       177.110000
# 75%       214.847500
# max       331.410000
# Training date range: 2022-11-17 00:00:00 to 2023-10-16 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     114.000000
# mean       90.513991
# std        21.941058
# min        47.240000
# 25%        69.390000
# 50%        96.070000
# 75%       107.840000
# max       157.120000
# Testing date range: 2023-10-17 00:00:00 to 2024-01-08 00:00:00
#
#
# Data for well X-341 has been saved to X-341_data.xlsx
# Training data description for well X-57:
#        ALLOC_OIL_AWO
# count     438.000000
# mean       59.797557
# std        10.729115
# min         0.000000
# 25%        54.725000
# 50%        60.060000
# 75%        66.660000
# max        99.460000
# Training date range: 2022-06-06 00:00:00 to 2023-08-17 00:00:00
#
# Testing data description for well {label}:
#        ALLOC_OIL_AWO
# count     140.000000
# mean       39.212964
# std        10.025835
# min        26.600000
# 25%        31.337500
# 50%        33.945000
# 75%        47.605000
# max        68.140000
# Testing date range: 2023-08-18 00:00:00 to 2023-12-05 00:00:00
#
#
# Data for well X-57 has been saved to X-57_data.xlsx

# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# Ensure plots directory exists
plots_dir = "RNN_blind"
if not os.path.exists(plots_dir):
    os.makedirs(plots_dir)

# Load the trained model
best_model = load_model("RNN_best.h5")

# Load blind test data for one well
blind_test_file = '65.xlsx'
well_name = os.path.splitext(blind_test_file)[0]  # Extract the well name from the file name
blind_test_df = pd.read_excel(blind_test_file)
blind_test_df['VOLUME_DATE'] = pd.to_datetime(blind_test_df['VOLUME_DATE'])
blind_test_df['VOLUME_DATE'] = blind_test_df['VOLUME_DATE'].dt.date
blind_test_df = blind_test_df.groupby('VOLUME_DATE', as_index=False).agg({'ALLOC_OIL_AWO': 'mean'})
blind_test_df = blind_test_df.set_index('VOLUME_DATE')

# Display descriptive statistics
desc = blind_test_df.describe()
print(f"Descriptive statistics for blind test data (well {well_name}):")
print(desc)

# Calculate date range
date_range = f"{blind_test_df.index.min()} to {blind_test_df.index.max()}"
print(f"Date range for blind test data (well {well_name}): {date_range}")
# Out:
# Descriptive statistics for blind test data (well 65):
#        ALLOC_OIL_AWO
# count     621.000000
# mean      114.248961
# std        41.687288
# min        35.760000
# 25%        77.740000
# 50%       118.240000
# 75%       148.460000
# max       234.840000
# Date range for blind test data (well 65): 2022-04-28 to 2024-01-08
